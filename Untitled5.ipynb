# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexCoilaJrt/Actividad/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import missingno as msno

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
android_games = pd.read_csv('/content/mineria de datos_s2-pract.csv')

# %%
android_games.head()
# Out:
#        Date  rank                                         title  \
# 0  1/1/2020     1                Garena Free Fire- World Series
# 1  1/2/2020     2                        PUBG MOBILE - Traverse
# 2  1/3/2020     3                     Mobile Legends: Bang Bang
# 3  1/4/2020     4                                   Brawl Stars
# 4  1/5/2020     5  Sniper 3D: Fun Free Online FPS Shooting Game
#
#    total ratings installs  average rating  growth (30 days)  growth (60 days)  \
# 0       86273129  500.0 M             4.0               2.1               6.9
# 1       37276732  500.0 M             4.0               1.8               3.6
# 2       26663595  100.0 M             4.0               1.5               3.2
# 3       17971552  100.0 M             4.0               1.4               4.4
# 4       14464235  500.0 M             4.0               0.8               1.5
#
#    price     category  5 star ratings  4 star ratings  3 star ratings  \
# ...

# %%
android_games.tail()
# Out:
#           Date  rank                             title  total ratings  \
# 1731  1/2/2020     2  The Four Winds by Kristin Hannah         120533
# 1732  1/3/2020     3    Every Last Fear by Alex Finlay         115437
# 1733  1/4/2020     4     Fake Accounts by Lauren Oyler         112408
# 1734  1/1/2020     1                      Barack Obama         111595
# 1735  1/2/2020     2                        Steve Jobs         110723
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# 1731    1.0 M             4.0              0.00               0.0    0.0
# 1732    5.0 M             2.0              0.20               0.5    0.0
# 1733    1.0 M             4.0              0.00               1.8    0.0
# 1734    1.0 M             3.0              0.90               2.3    0.0
# 1735   10.0 M             4.0              0.76               1.9    0.0
#
#             category  5 star ratings  4 star ratings  3 star ratings  \
# ...

# %%
android_games.sample(4)
# Out:
#                Date  rank                      title  total ratings installs  \
# 1328       1/3/2020     3                Score! Hero        6856324  100.0 M
# 622        4/6/2020    97  Slots: Free Slot Machines          86366    1.0 M
# 520   April 4, 2020    95           Cribbage Classic          97018    1.0 M
# 314       1/15/2020    15                Ludo Star 2         597656   10.0 M
#
#       average rating  growth (30 days)  growth (60 days)  price     category  \
# 1328             4.0               0.5               1.1    0.0  GAME SPORTS
# 622              4.0               0.3               0.9    0.0  GAME CASINO
# 520              4.0               0.7               1.3    0.0    GAME CARD
# 314              4.0               2.8               5.5    0.0   GAME BOARD
#
#       5 star ratings  4 star ratings  3 star ratings  2 star ratings  \
# 1328         4551071          837222          464347          222878
# ...

# %%
android_games.shape
# Out:
# (1736, 16)

# %%
android_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1736 non-null   object
#  1   rank              1736 non-null   int64
#  2   title             1736 non-null   object
#  3   total ratings     1736 non-null   int64
#  4   installs          1736 non-null   object
#  5   average rating    1728 non-null   float64
#  6   growth (30 days)  1736 non-null   float64
#  7   growth (60 days)  1736 non-null   float64
#  8   price             1736 non-null   float64
#  9   category          1736 non-null   object
#  10  5 star ratings    1736 non-null   int64
#  11  4 star ratings    1736 non-null   int64
#  12  3 star ratings    1736 non-null   int64
#  13  2 star ratings    1736 non-null   int64
#  14  1 star ratings    1736 non-null   int64
#  15  paid              1729 non-null   object
# ...

# %%
android_games.describe().T
# Out:
#                    count          mean           std      min        25%  \
# rank              1736.0  5.022005e+01  2.902510e+01      1.0      25.00
# total ratings     1736.0  1.110679e+06  3.988018e+06  32993.0  174227.25
# average rating    1728.0  3.906250e+00  2.955102e-01      2.0       4.00
# growth (30 days)  1736.0  3.206262e+02  6.008528e+03      0.0       0.10
# growth (60 days)  1736.0  1.221391e+02  2.250002e+03      0.0       0.20
# price             1736.0  1.090438e-02  2.146162e-01      0.0       0.00
# 5 star ratings    1736.0  7.964405e+05  2.948668e+06  13975.0  126826.50
# 4 star ratings    1736.0  1.189283e+05  3.232236e+05   2451.0   20566.25
# 3 star ratings    1736.0  5.870517e+04  1.668288e+05    718.0    9609.00
# 2 star ratings    1736.0  2.824129e+04  9.569178e+04    266.0    4235.00
# 1 star ratings    1736.0  1.083608e+05  5.046927e+05    545.0   12653.00
#
#                        50%        75%          max
# ...

# %%
plt.hist(android_games['average rating'])
# Out:
# (array([   2.,    0.,    0.,    0.,    0.,  158.,    0.,    0.,    0.,
#         1568.]),
#  array([2. , 2.2, 2.4, 2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x= 'paid', data=android_games)
# Out:
# <Axes: xlabel='paid', ylabel='count'>

# %%
sns.countplot(x='paid', data=android_games, stat='percent').set(ylim=(0,100), ylabel='Porcentaje (%) de videojuegos gratis y de pago')
# Out:
# [(0.0, 100.0), Text(0, 0.5, 'Porcentaje (%) de videojuegos gratis y de pago')]

# %%
(android_games['paid'].value_counts(normalize=True) * 100).plot(kind='bar', title='Porcentaje (%) de videojuegos gratis y de pago')
# Out:
# <Axes: title={'center': 'Porcentaje (%) de videojuegos gratis y de pago'}, xlabel='paid'>

# %%
android_games.describe(include='O')
# Out:
#             Date      title installs   category   paid
# count       1736       1736     1736       1736   1729
# unique       121       1681        9         22      2
# top     1/3/2020  Solitaire   10.0 M  GAME CARD  False
# freq          21         36      806        125   1691

# %%
android_games['category'].unique()
# Out:
# array(['GAME ACTION', 'game action', 'GAME ADVENTURE', 'GAME ARCADE',
#        'GAME BOARD', 'GAME CARD', 'game card', 'GAME CASINO',
#        'GAME CASUAL', 'GAME EDUCATIONAL', 'GAME MUSIC', 'game music',
#        'GAME PUZZLE', 'GAME RACING', 'GAME ROLE PLAYING',
#        'GAME SIMULATION', 'GAME SPORTS', 'GAME STRATEGY', 'GAME TRIVIA',
#        'GAME WORD', 'FICTION BOOK', 'BIOGRAPHY BOOK'], dtype=object)

# %%
android_games['Date'].unique()
# Out:
# array(['1/1/2020', '1/2/2020', '1/3/2020', '1/4/2020', '1/5/2020',
#        '1/6/2020', '1/7/2020', '1/8/2020', '1/9/2020', '1/10/2020',
#        '1/11/2020', '1/12/2020', '1/13/2020', '1/14/2020', '1/15/2020',
#        '1/16/2020', '1/17/2020', '1/18/2020', '1/19/2020', '1/20/2020',
#        '1/21/2020', '1/22/2020', '1/23/2020', '1/24/2020', '1/25/2020',
#        '1/26/2020', '1/27/2020', '1/28/2020', '1/29/2020', '1/30/2020',
#        '1/31/2020', '2/1/2020', '2/2/2020', '2/3/2020', '2/4/2020',
#        '2/5/2020', '2/6/2020', '2/7/2020', '2/8/2020', '2/9/2020',
#        '2/10/2020', '2/11/2020', '2/12/2020', '2/13/2020', '2/14/2020',
#        '2/15/2020', '2/16/2020', '2/17/2020', '2/18/2020', '2/19/2020',
#        '2/20/2020', '2/21/2020', '2/22/2020', '2/23/2020', '2/24/2020',
#        '2/25/2020', '2/26/2020', '2/27/2020', '2/28/2020', '2/29/2020',
#        '3/1/2020', '3/2/2020', '3/3/2020', '3/4/2020', '3/5/2020',
# ...

# %%
display(android_games.isnull().sum())
# Out:
# Date                0
# rank                0
# title               0
# total ratings       0
# installs            0
# average rating      8
# growth (30 days)    0
# growth (60 days)    0
# price               0
# category            0
# 5 star ratings      0
# 4 star ratings      0
# 3 star ratings      0
# 2 star ratings      0
# 1 star ratings      0
# paid                7
# dtype: int64

# %%
display(android_games['category'].str.lower().unique())
# Out:
# array(['game action', 'game adventure', 'game arcade', 'game board',
#        'game card', 'game casino', 'game casual', 'game educational',
#        'game music', 'game puzzle', 'game racing', 'game role playing',
#        'game simulation', 'game sports', 'game strategy', 'game trivia',
#        'game word', 'fiction book', 'biography book'], dtype=object)

# %%
android_games['Date'] = pd.to_datetime(android_games['Date'], errors='coerce')
display(android_games[android_games['Date'].isna()])  # Muestra filas donde la fecha falló
# Out:
#     Date  rank                                              title  \
# 499  NaT    80  Solitaire Showtime: Tri Peaks Solitaire Free &...
# 500  NaT    81                              한게임 신맞고 : 대한민국 원조 고스톱
# 501  NaT    82  Absolute Bingo- Free Bingo Games Offline or On...
# 502  NaT    83                       Batak HD - İnternetsiz Batak
# 503  NaT    84                       Mega Hit Poker: Texas Holdem
# 504  NaT    85                                   Spider Solitaire
# 505  NaT    86                                          Solitaire
# 506  NaT    86                                          Solitaire
# 507  NaT    86                                          Solitaire
# 508  NaT    87                                     LG Smart Truco
# 509  NaT    88     Solitaire Cruise: Classic Tripeaks Cards Games
# 510  NaT    89                                     Gin Rummy Free
# 511  NaT    90                                          Solitaire
# ...

# %%
missing_values_count = android_games.isna().sum()
display(missing_values_count)

missing_values_percentage = (missing_values_count / len(android_games)) * 100
display(missing_values_percentage)
# Out:
# Date                27
# rank                 0
# title                0
# total ratings        0
# installs             0
# average rating       8
# growth (30 days)     0
# growth (60 days)     0
# price                0
# category             0
# 5 star ratings       0
# 4 star ratings       0
# 3 star ratings       0
# 2 star ratings       0
# 1 star ratings       0
# paid                 7
# dtype: int64
# Date                1.555300
# rank                0.000000
# title               0.000000
# total ratings       0.000000
# installs            0.000000
# average rating      0.460829
# growth (30 days)    0.000000
# growth (60 days)    0.000000
# price               0.000000
# category            0.000000
# 5 star ratings      0.000000
# 4 star ratings      0.000000
# 3 star ratings      0.000000
# 2 star ratings      0.000000
# 1 star ratings      0.000000
# paid                0.403226
# dtype: float64

# %%
msno.bar(android_games)
plt.show()

# %%
android_games[android_games.isna().any(axis=1)]
# Out:
#            Date  rank                                              title  \
# 55   2020-02-25    56                              PPSSPP - PSP emulator
# 113  2020-01-14    14                                          Growtopia
# 334  2020-02-04    35                                        Pinball Pro
# 336  2020-02-06    37                               Woody Block Puzzle ®
# 477  2020-02-29    60                                             Reigns
# 499         NaT    80  Solitaire Showtime: Tri Peaks Solitaire Free &...
# 500         NaT    81                              한게임 신맞고 : 대한민국 원조 고스톱
# 501         NaT    82  Absolute Bingo- Free Bingo Games Offline or On...
# 502         NaT    83                       Batak HD - İnternetsiz Batak
# 503         NaT    84                       Mega Hit Poker: Texas Holdem
# 504         NaT    85                                   Spider Solitaire
# 505         NaT    86                                          Solitaire
# ...
